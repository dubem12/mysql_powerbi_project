# %%
import pandas as pd

# %%
df = pd.read_csv('grouped_melted.csv')

df
# Out:
#        country_id                                product  product_code  \
# 0         Albania               engineered wood products             4
# 1         Albania               engineered wood products             4
# 2         Albania               engineered wood products             4
# 3         Albania              paper,print and packaging             8
# 4         Albania              paper,print and packaging             8
# ...           ...                                    ...           ...
# 65500  Uzbekistan                       wooden furniture            25
# 65501  Uzbekistan  wooden wrapping and packing equipment            26
# 65502  Uzbekistan  wooden wrapping and packing equipment            26
# 65503  Uzbekistan                               woodpulp            27
# 65504  Uzbekistan                               woodpulp            27
#
#              flow       unit  year     value
# 0         IMPORTS   1000 US$  2007  15888.03
# ...

# %% [markdown]
# convert all rows into a list of tuples

# %%
y= []

for i in range (len(df)):
    x= tuple(df.iloc[i])
    y.append(x)

y
# Out:
# [('Albania',
#   'engineered wood products',
#   4,
#   'IMPORTS',
#   '1000 US$',
#   2007,
#   15888.03),
#  ('Albania',
#   'engineered wood products',
#   4,
#   'IMPORTS',
#   '1000 m3',
#   2007,
#   140.80999999999997),
#  ('Albania',
#   'engineered wood products',
#   4,
#   'PRODUCTION',
#   '1000 m3',
#   2007,
#   12.0),
#  ('Albania',
#   'paper,print and packaging',
#   8,
#   'EXPORTS',
#   '1000 m.t.',
#   2007,
#   0.08),
#  ('Albania',
#   'paper,print and packaging',
#   8,
#   'IMPORTS',
#   '1000 m.t.',
#   2007,
#   20.63),
#  ('Albania', 'pulpwood', 11, 'IMPORTS', '1000 m.t.', 2007, 4.3),
#  ('Albania', 'roundwood', 14, 'EXPORTS', '1000 US$', 2007, 1750.4599999999998),
#  ('Albania', 'roundwood', 14, 'EXPORTS', '1000 m3', 2007, 58.59),
#  ('Albania', 'roundwood', 14, 'IMPORTS', '1000 US$', 2007, 343.42),
#  ('Albania', 'roundwood', 14, 'IMPORTS', '1000 m3', 2007, 2.95),
#  ('Albania', 'roundwood', 14, 'REMOVALS', '1000 m3', 2007, 1149.97),
#  ('Albania',
# ...

# %%
#save the list of tuples to a file

file = open('product.txt', 'w')

for tuple in y:
    file.write(str(tuple) + ',' + '\n')

file.close()

# %% [markdown]
# let´s
